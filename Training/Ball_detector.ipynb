# %%
# %pip install roboflow
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Getting Dataset

# %%
from roboflow import Roboflow

# %%
rf = Roboflow(api_key="pY8JzZrmXbh4nDt9XUWm")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
#!yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
#!yolo task=detect mode=train model=yolov5l6u.pt data=C:/Users/YY/datasets/tennis/data.yaml epochs=100 imgsz=640
#dataset_location = r"C:\Users\YY\Desktop\Tennis System"  # Update this path
#!yolo task=detect mode=train model=yolov5l6u.pt data={dataset_location}/data.yaml epochs=100 imgsz=640
# !yolo task=detect mode=train model=yolov5l6u.pt data ='{dataset.location}/data.yaml' epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.78 🚀 Python-3.12.4 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i7-11800H 2.30GHz)
# ...

# %%
from ultralytics import YOLO
model = YOLO('C:\Users\YY\Desktop\Tennis System\models\last.pt')
print(model.names)
# Out:
#   Cell In[14], line 2
#     model = YOLO('C:\Users\YY\Desktop\Tennis System\models\last.pt')
#                  ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
